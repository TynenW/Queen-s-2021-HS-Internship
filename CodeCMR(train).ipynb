# %% [markdown]
# <a href="https://colab.research.google.com/github/TynenW/Queen-s-2021-HS-Internship/blob/main/CodeCMR(train).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import python library "pandas" as pd for short form.
import pandas as pd
import networkx as nx

#Call on data frame "test".
df = pd.read_pickle("/content/drive/MyDrive/Internship and Award Applications/Queen's/Assignment/train.pkl")
print(df.columns)                   # 33 columns

#We use df.iloc to specify rows and columns by their integer index.
sample = df.iloc[0]
src, bin = sample['c_label'], sample['gcc-x64-O0']

#Displays data in a tabular format.
display(df)

#Drops any duplicate values.
df.drop_duplicates(keep = False, inplace = True)

#print(src)

#Executes path to the file known as bin.
g = nx.read_gpickle("/content/drive/MyDrive/Internship and Award Applications/Queen's/all-arch-nx/1682_6/gcc-x64-O0.nx")

#Bin path (cheating)
#/content/drive/MyDrive/Internship and Award Applications/Queen's/Assignment/all-arch-nx/1682_6/gcc-x64-O0.nx
                                                                          #./all-arch-nx/1682_6/gcc-x64-O0.nx


print(g.graph)                      # binary code literal features, we only use c_int and c_str
print(g.nodes.data('feat'))         # binary code CFG features
# Out:
# Index(['c_label', 'gcc-x86-O0', 'gcc-x86-O1', 'gcc-x86-O2', 'gcc-x86-O3',
#        'gcc-x64-O0', 'gcc-x64-O1', 'gcc-x64-O2', 'gcc-x64-O3', 'gcc-arm-O0',
#        'gcc-arm-O1', 'gcc-arm-O2', 'gcc-arm-O3', 'gcc-arm64-O0',
#        'gcc-arm64-O1', 'gcc-arm64-O2', 'gcc-arm64-O3', 'clang-x86-O0',
#        'clang-x86-O1', 'clang-x86-O2', 'clang-x86-O3', 'clang-x64-O0',
#        'clang-x64-O1', 'clang-x64-O2', 'clang-x64-O3', 'clang-arm-O0',
#        'clang-arm-O1', 'clang-arm-O2', 'clang-arm-O3', 'clang-arm64-O0',
#        'clang-arm64-O1', 'clang-arm64-O2', 'clang-arm64-O3'],
#       dtype='object')
#                                                  c_label  ...                            clang-arm64-O3
# 0      void benchmarkHsearchBuildTime (char * name)\n...  ...  ./all-arch-nx/10527_10/clang-arm64-O3.nx
# 1      extern void gdImageDestroy (gdImagePtr im)\n{\...  ...   ./all-arch-nx/43883_4/clang-arm64-O3.nx
# 2      static PyObject *__Pyx_GetItemInt_Generic(PyOb...  ...    ./all-arch-nx/270_94/clang-arm64-O3.nx
# 3      static\nvoid goalreachable_guards_inserter_hel...  ...   ./all-arch-nx/63935_8/clang-arm64-O3.nx
# 4      int window_is_valid(context_t *context, const ...  ...   ./all-arch-nx/70019_8/clang-arm64-O3.nx
# ...                                                  ...  ...                                       ...
# 29995  static gl_list_iterator_t\ngl_tree_iterator_fr...  ...  ./all-arch-nx/52743_39/clang-arm64-O3.nx
